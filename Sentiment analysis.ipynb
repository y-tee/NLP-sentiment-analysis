# %%
import numpy as np
import pandas as pd
import string
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
messages = [line.rstrip() for line in open("C:/Users/Yingting L/Desktop/sentiment/maideasy comment text.txt")]

# %%
messages[87]
# Out:
# '"maideasy crew dtg by 5 minutes, but back on time. ?? work he is good, but i always work neatly, not byk damn, make everything what we want .. thank you for your service ..! ??"'

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\Yingting
# [nltk_data]     L\AppData\Roaming\nltk_data...
# True

# %%
def nltk_sentiment(sentence):
    
    nltk_sentiment = SentimentIntensityAnalyzer()
    score = nltk_sentiment.polarity_scores(sentence)
    return score

# %%
nltk_sentiment("the food is not bad")
# Out:
# {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'compound': 0.431}

# %%
nltk_sentiment("the food not good")
# Out:
# {'neg': 0.445, 'neu': 0.555, 'pos': 0.0, 'compound': -0.3412}

# %%
nltk_sentiment("the food is bad")
# Out:
# {'neg': 0.538, 'neu': 0.462, 'pos': 0.0, 'compound': -0.5423}

# %%
nltk_sentiment("the food is good")
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
pd.DataFrame(data,index=[0])
# Out:
#      neg    neu    pos  compound
# 0  0.029  0.776  0.195    0.9343

# %%
list=[]
i=1
while i<len(messages):
    dat=nltk_sentiment(messages[i])
    list.append(dat)
    i=i+1

# %%
data=pd.DataFrame(list)

# %%
data
# Out:
#     compound    neg    neu    pos
# 0     0.9343  0.029  0.776  0.195
# 1     0.8996  0.049  0.686  0.265
# 2     0.7845  0.028  0.809  0.164
# 3     0.9042  0.000  0.629  0.371
# 4     0.6808  0.000  0.844  0.156
# 5     0.8466  0.048  0.808  0.144
# 6     0.8807  0.000  0.472  0.528
# 7     0.7758  0.057  0.728  0.215
# 8     0.4199  0.000  0.642  0.358
# 9     0.9601  0.000  0.713  0.287
# 10   -0.7717  0.191  0.730  0.080
# 11    0.7346  0.000  0.721  0.279
# 12    0.7964  0.000  0.633  0.367
# 13    0.9635  0.039  0.744  0.217
# 14    0.4404  0.000  0.791  0.209
# 15    0.0000  0.000  1.000  0.000
# 16    0.0000  0.000  1.000  0.000
# 17    0.0000  0.000  1.000  0.000
# 18   -0.4767  0.100  0.900  0.000
# 19   -0.3252  0.318  0.682  0.000
# 20    0.9748  0.000  0.672  0.328
# 21    0.8957  0.000  0.505  0.495
# 22    0.6643  0.141  0.621  0.238
# 23    0.9845  0.049  0.733  0.218
# 24    0.9476  0.000  0.582  0.418
# 25    0.5093  0.000  0.737  0.263
# ...

# %%
data.to_csv('maidesy sentiment analysis.csv')
